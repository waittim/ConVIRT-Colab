# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
import os
cur_path = "/content/drive/MyDrive/ConVIRT-pytorch/"
os.chdir(cur_path)
# !pwd
# Out:
# /content/drive/MyDrive/ConVIRT-pytorch

# %%
#!wget -r -N -c -np --user zekunwang --ask-password https://physionet.org/files/mimic-cxr/2.0.0/
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#
# physionet.org/files     [ <=>                ]     607  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-03-22 03:54:44 (46.3 MB/s) - ‘physionet.org/files/mimic-cxr/2.0.0/files/p14/p14743029/s53229200/index.html’ saved [607]
#
# --2021-03-22 03:54:44--  https://physionet.org/files/mimic-cxr/2.0.0/files/p14/p14743029/s54690557/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-cxr/2.0.0/files/p14/p14743029/s54690557/index.html’
#
# physionet.org/files     [ <=>                ]     454  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-03-22 03:54:44 (34.0 MB/s) - ‘physionet.org/files/mimic-cxr/2.0.0/files/p14/p14743029/s54690557/index.html’ saved [454]
#
# --2021-03-22 03:54:44--  https://physionet.org/files/mimic-cxr/2.0.0/files/p14/p14743029/s57380122/
# ...

# %%
# !cd /content/drive/MyDrive/ConVIRT-pytorch/physionet.org/files/mimic-cxr/2.0.0/
# !pwd
# !gzip -d cxr-record-list.csv.gz
# !gzip -d cxr-study-list.csv.gz

# !cd /content/drive/MyDrive/ConVIRT-pytorch/
# Out:
# /content/drive/MyDrive/ConVIRT-pytorch
# gzip: cxr-record-list.csv.gz: No such file or directory
# gzip: cxr-study-list.csv.gz: No such file or directory

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not find a version that satisfies the requirement cudatoolkit==10.2 (from -r requirements.txt (line 1)) (from versions: none)
# ERROR: No matching distribution found for cudatoolkit==10.2 (from -r requirements.txt (line 1))

# %%
# !pip install pyyaml==5.3.1
# Out:
# ...
#      |████████████████████████████████| 276kB 8.6MB/s
# ...
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44620 sha256=b53a2fe3a2b7adafc2edf50685e97c65aa4bec8d3a7cae20597c589522fa9b40
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built pyyaml
# ...
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.0MB 9.6MB/s
# ...
#      |████████████████████████████████| 890kB 48.6MB/s
# ...
#      |████████████████████████████████| 3.2MB 55.5MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=ac688febff6c13af8dcc4a5dd4b504af98598eb794f4183bbdaab899e2353c11
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
import yaml
yaml.__version__
# Out:
# '5.3.1'

# %%
import numpy as np
import pandas as pd

# %%
record = pd.read_csv('/content/drive/MyDrive/ConVIRT-pytorch/physionet.org/files/mimic-cxr/2.0.0/cxr-record-list.csv')
study = pd.read_csv('/content/drive/MyDrive/ConVIRT-pytorch/physionet.org/files/mimic-cxr/2.0.0/cxr-study-list.csv')

# %%
record
# Out:
#         subject_id  ...                                               path
# 0         10000032  ...  files/p10/p10000032/s50414267/02aa804e-bde0afd...
# 1         10000032  ...  files/p10/p10000032/s50414267/174413ec-4ec4c1f...
# 2         10000032  ...  files/p10/p10000032/s53189527/2a2277a9-b0ded15...
# 3         10000032  ...  files/p10/p10000032/s53189527/e084de3b-be89b11...
# 4         10000032  ...  files/p10/p10000032/s53911762/68b5c4b1-227d048...
# ...            ...  ...                                                ...
# 377105    19999733  ...  files/p19/p19999733/s57132437/428e2c18-5721d8f...
# 377106    19999733  ...  files/p19/p19999733/s57132437/58c403aa-35ff8bd...
# 377107    19999987  ...  files/p19/p19999987/s55368167/58766883-376a15c...
# 377108    19999987  ...  files/p19/p19999987/s58621812/7ba273af-3d290f8...
# 377109    19999987  ...  files/p19/p19999987/s58971208/1a1fe7e3-cbac5d9...
#
# [377110 rows x 4 columns]

# %%
# !python run.py
# Out:
# 2021-03-25 20:35:00.141046: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# Running on: cuda
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:285: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %%
text_path = '/content/drive/MyDrive/CL-medical-image-text-pair/data/ecgen-radiology-txt/CXR1237_IM-0159-1002.txt'
with open(text_path) as f:
    content = f.readlines()
content = content[0].replace("\n", "")
