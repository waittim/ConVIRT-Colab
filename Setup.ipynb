# %% [markdown]
# # Setup
#
# This notebook will help you train the contrastive learning model. Before running this notebook, please make sure you have modified the **config.yaml**.
#
# ## Set up Google Colab environment
#
# For running the model in Colab, we need to mount to the path which we cloned the repository.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
cur_path = "/content/drive/MyDrive/ConVIRT-Colab/"
os.chdir(cur_path)
# !pwd
# Out:
# /content/drive/MyDrive/ConVIRT-Colab

# %% [markdown]
# Install necessary modules.

# %%
# !pip install pyyaml==5.3.1
# !pip install transformers

# %% [markdown]
# ## Training
#
# After running the following code, the training will start. You will need a long time to wait for the result.

# %%
# !python run.py

# %% [markdown]
# During the process, you can check **tensorboard.ipynb** to monitor the training.
